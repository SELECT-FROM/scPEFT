# %% [markdown]
# # PEFT(Parameter-Efficient Fine-Tuning) Pre-trained Model for Perturbation Prediction

# %%
import json
import os
import sys
import time
import copy
from pathlib import Path
from typing import Iterable, List, Tuple, Dict, Union, Optional
import warnings

import torch
import numpy as np
import matplotlib
from torch import nn
from torch.nn import functional as F
from torchtext.vocab import Vocab
from torchtext._torchtext import (
    Vocab as VocabPybind,
)
from torch_geometric.loader import DataLoader
from gears import PertData, GEARS
from gears.inference import compute_metrics, deeper_analysis, non_dropout_analysis
from gears.utils import create_cell_graph_dataset_for_prediction

sys.path.insert(0, "../")

import scgpt as scg
from scgpt.model import TransformerGenerator
from scgpt.loss import (
    masked_mse_loss,
    criterion_neg_log_bernoulli,
    masked_relative_error,
)
from scgpt.tokenizer import tokenize_batch, pad_batch, tokenize_and_pad_batch
from scgpt.tokenizer.gene_tokenizer import GeneVocab
from scgpt.utils import set_seed, map_raw_id_to_vocab_id, compute_perturbation_metrics
from scgpt.utils import set_seed, PeftConfig, freeze_parameters, DownstreamTasks, load_pretrained

matplotlib.rcParams["savefig.transparent"] = False
warnings.filterwarnings("ignore")

set_seed(42)

# %%
# settings for parameter efficient fine tuning
peft = "ENCODER"
assert peft in [False, "HYBRID", "ENCODER", "TOKEN", "PREFIX", "LORA"]
peft_config = PeftConfig(peft_type=peft, use_default_settings=True).to_dict()

# settings for data prcocessing
pad_token = "<pad>"
special_tokens = [pad_token, "<cls>", "<eoc>"]
pad_value = 0  # for padding values
pert_pad_id = 0
include_zero_gene = "all"
max_seq_len = 1536

# settings for training
MLM = True  # whether to use masked language modeling, currently it is always on.
CLS = False  # celltype classification objective
CCE = False  # Contrastive cell embedding objective
MVC = False  # Masked value prediction for cell embedding
ECS = False  # Elastic cell similarity objective
amp = True
load_model = "../save/scGPT_human"
load_param_prefixs = [
    "encoder",
    "value_encoder",
    "transformer_encoder",
]

# settings for optimizer
lr = 1e-4  # or 1e-4
batch_size = 20
eval_batch_size = 20
epochs = 15
schedule_interval = 1
early_stop = 10

# settings for the model
embsize = 512  # embedding dimension
d_hid = 512  # dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 12  # number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 8  # number of heads in nn.MultiheadAttention
n_layers_cls = 3
dropout = 0  # dropout probability
use_fast_transformer = False  # whether to use fast transformer

# logging
log_interval = 100

# dataset and evaluation choices
data_name = "adamson"
split = "simulation"
if data_name == "norman":
    perts_to_plot = ["SAMD1+ZBTB1"]
elif data_name == "adamson":
    perts_to_plot = ["KCTD16+ctrl"]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
save_dir = Path(f"./save/peft_perturb_{data_name}-{time.strftime('%b%d-%H-%M')}/")
save_dir.mkdir(parents=True, exist_ok=True)
print(f"saving to {save_dir}")

logger = scg.logger
scg.utils.add_file_handler(logger, save_dir / "run.log")
# log running date and current git commit
logger.info(f"Running on {time.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# saving to save/peft_perturb_adamson-Nov03-03-23
# scGPT - INFO - Running on 2024-11-03 03:23:15

# %%
pert_data = PertData("./data")
pert_data.load(data_name=data_name)
pert_data.prepare_split(split=split, seed=1)
pert_data.get_dataloader(batch_size=batch_size, test_batch_size=eval_batch_size)
# Out:
# Found local copy...
# Local copy of pyg dataset is detected. Loading...
# Done!
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:22
# Done!
# Creating dataloaders....
# Done!

# %%
if load_model is not None:
    model_dir = Path(load_model)
    model_config_file = model_dir / "args.json"
    model_file = model_dir / "best_model.pt"
    vocab_file = model_dir / "vocab.json"

    vocab = GeneVocab.from_file(vocab_file)
    for s in special_tokens:
        if s not in vocab:
            vocab.append_token(s)

    pert_data.adata.var["id_in_vocab"] = [
        1 if gene in vocab else -1 for gene in pert_data.adata.var["gene_name"]
    ]
    gene_ids_in_vocab = np.array(pert_data.adata.var["id_in_vocab"])
    logger.info(
        f"match {np.sum(gene_ids_in_vocab >= 0)}/{len(gene_ids_in_vocab)} genes "
        f"in vocabulary of size {len(vocab)}."
    )
    genes = pert_data.adata.var["gene_name"].tolist()

    # model
    with open(model_config_file, "r") as f:
        model_configs = json.load(f)
    logger.info(
        f"Resume model from {model_file}, the model args will override the "
        f"config {model_config_file}."
    )
    embsize = model_configs["embsize"]
    nhead = model_configs["nheads"]
    d_hid = model_configs["d_hid"]
    nlayers = model_configs["nlayers"]
    n_layers_cls = model_configs["n_layers_cls"]
else:
    genes = pert_data.adata.var["gene_name"].tolist()
    vocab = Vocab(
        VocabPybind(genes + special_tokens, None)
    )  # bidirectional lookup [gene <-> int]
vocab.set_default_index(vocab["<pad>"])
gene_ids = np.array(
    [vocab[gene] if gene in vocab else vocab["<pad>"] for gene in genes], dtype=int
)
n_genes = len(genes)
# Out:
# scGPT - INFO - match 4399/5060 genes in vocabulary of size 60697.
# scGPT - INFO - Resume model from ../save/scGPT_human/best_model.pt, the model args will override the config ../save/scGPT_human/args.json.

# %%
ntokens = len(vocab)  # size of vocabulary
model = TransformerGenerator(
    ntokens,
    embsize,
    nhead,
    d_hid,
    nlayers,
    nlayers_cls=n_layers_cls,
    n_cls=1,
    vocab=vocab,
    dropout=dropout,
    pad_token=pad_token,
    pad_value=pad_value,
    pert_pad_id=pert_pad_id,
    use_fast_transformer=use_fast_transformer,
    peft_config=peft_config
)
if load_model is not None:
    load_pretrained(model, torch.load(model_file), prefix=load_param_prefixs, verbose=False)

model.to(device)
pre_freeze_param_count = sum(dict((p.data_ptr(), p.numel()) for p in model.parameters() if p.requires_grad).values())

# Freeze params
if peft:
    freeze_parameters(model, DownstreamTasks.Perturbation)

post_freeze_param_count = sum(dict((p.data_ptr(), p.numel()) for p in model.parameters() if p.requires_grad).values())

logger.info("-" * 89)
learnable_params = {k: v for k, v in model.named_parameters() if v.requires_grad}
for k, v in learnable_params.items():
    logger.info(f"Learnable params {k} with shape {v.shape}")

logger.info("Total Pre freeze Params: %.2fM" % (pre_freeze_param_count / 1e6,))
logger.info("Total Post freeze Params: %.2fM" % (post_freeze_param_count / 1e6,))
# Out:
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Learnable params value_encoder.linear1.weight with shape torch.Size([512, 1])
# scGPT - INFO - Learnable params value_encoder.linear1.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params value_encoder.linear2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Learnable params value_encoder.linear2.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params value_encoder.norm.weight with shape torch.Size([512])
# scGPT - INFO - Learnable params value_encoder.norm.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params pert_encoder.weight with shape torch.Size([3, 512])
# scGPT - INFO - Learnable params transformer_encoder.layers.0.space_adapter.fc1.weight with shape torch.Size([256, 512])
# scGPT - INFO - Learnable params transformer_encoder.layers.0.space_adapter.fc1.bias with shape torch.Size([256])
# scGPT - INFO - Learnable params transformer_encoder.layers.0.space_adapter.fc2.weight with shape torch.Size([512, 256])
# scGPT - INFO - Learnable params transformer_encoder.layers.0.space_adapter.fc2.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params transformer_encoder.layers.1.space_adapter.fc1.weight with shape torch.Size([256, 512])
# scGPT - INFO - Learnable params transformer_encoder.layers.1.space_adapter.fc1.bias with shape torch.Size([256])
# scGPT - INFO - Learnable params transformer_encoder.layers.1.space_adapter.fc2.weight with shape torch.Size([512, 256])
# scGPT - INFO - Learnable params transformer_encoder.layers.1.space_adapter.fc2.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params transformer_encoder.layers.2.space_adapter.fc1.weight with shape torch.Size([256, 512])
# scGPT - INFO - Learnable params transformer_encoder.layers.2.space_adapter.fc1.bias with shape torch.Size([256])
# scGPT - INFO - Learnable params transformer_encoder.layers.2.space_adapter.fc2.weight with shape torch.Size([512, 256])
# scGPT - INFO - Learnable params transformer_encoder.layers.2.space_adapter.fc2.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params transformer_encoder.layers.3.space_adapter.fc1.weight with shape torch.Size([256, 512])
# scGPT - INFO - Learnable params transformer_encoder.layers.3.space_adapter.fc1.bias with shape torch.Size([256])
# scGPT - INFO - Learnable params transformer_encoder.layers.3.space_adapter.fc2.weight with shape torch.Size([512, 256])
# scGPT - INFO - Learnable params transformer_encoder.layers.3.space_adapter.fc2.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params transformer_encoder.layers.4.space_adapter.fc1.weight with shape torch.Size([256, 512])
# scGPT - INFO - Learnable params transformer_encoder.layers.4.space_adapter.fc1.bias with shape torch.Size([256])
# scGPT - INFO - Learnable params transformer_encoder.layers.4.space_adapter.fc2.weight with shape torch.Size([512, 256])
# scGPT - INFO - Learnable params transformer_encoder.layers.4.space_adapter.fc2.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params transformer_encoder.layers.5.space_adapter.fc1.weight with shape torch.Size([256, 512])
# scGPT - INFO - Learnable params transformer_encoder.layers.5.space_adapter.fc1.bias with shape torch.Size([256])
# scGPT - INFO - Learnable params transformer_encoder.layers.5.space_adapter.fc2.weight with shape torch.Size([512, 256])
# scGPT - INFO - Learnable params transformer_encoder.layers.5.space_adapter.fc2.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params decoder.coeff_decoder.fc.0.weight with shape torch.Size([512, 512])
# scGPT - INFO - Learnable params decoder.coeff_decoder.fc.0.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params decoder.coeff_decoder.fc.2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Learnable params decoder.coeff_decoder.fc.2.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params decoder.coeff_decoder.fc.4.weight with shape torch.Size([1, 512])
# scGPT - INFO - Learnable params decoder.coeff_decoder.fc.4.bias with shape torch.Size([1])
# scGPT - INFO - Learnable params decoder.bias_decoder.fc.0.weight with shape torch.Size([512, 512])
# scGPT - INFO - Learnable params decoder.bias_decoder.fc.0.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params decoder.bias_decoder.fc.2.weight with shape torch.Size([512, 512])
# scGPT - INFO - Learnable params decoder.bias_decoder.fc.2.bias with shape torch.Size([512])
# scGPT - INFO - Learnable params decoder.bias_decoder.fc.4.weight with shape torch.Size([1, 512])
# scGPT - INFO - Learnable params decoder.bias_decoder.fc.4.bias with shape torch.Size([1])
# scGPT - INFO - Total Pre freeze Params: 52.91M
# scGPT - INFO - Total Post freeze Params: 2.90M

# %%
criterion = masked_mse_loss
criterion_cls = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, schedule_interval, gamma=0.9)
scaler = torch.cuda.amp.GradScaler(enabled=amp)


def train(model: nn.Module, train_loader: torch.utils.data.DataLoader) -> None:
    """
    Train the model for one epoch.
    """
    model.train()
    total_loss, total_mse = 0.0, 0.0
    start_time = time.time()

    num_batches = len(train_loader)
    for batch, batch_data in enumerate(train_loader):
        batch_size = len(batch_data.y)
        batch_data.to(device)
        x: torch.Tensor = batch_data.x  # (batch_size * n_genes, 2)
        ori_gene_values = x[:, 0].view(batch_size, n_genes)
        pert_flags = x[:, 1].long().view(batch_size, n_genes)
        target_gene_values = batch_data.y  # (batch_size, n_genes)

        if include_zero_gene in ["all", "batch-wise"]:
            if include_zero_gene == "all":
                input_gene_ids = torch.arange(n_genes, device=device, dtype=torch.long)
            else:
                input_gene_ids = (
                    ori_gene_values.nonzero()[:, 1].flatten().unique().sort()[0]
                )
            # sample input_gene_id
            if len(input_gene_ids) > max_seq_len:
                input_gene_ids = torch.randperm(len(input_gene_ids), device=device)[
                                 :max_seq_len
                                 ]
            input_values = ori_gene_values[:, input_gene_ids]
            input_pert_flags = pert_flags[:, input_gene_ids]
            target_values = target_gene_values[:, input_gene_ids]

            mapped_input_gene_ids = map_raw_id_to_vocab_id(input_gene_ids, gene_ids)
            mapped_input_gene_ids = mapped_input_gene_ids.repeat(batch_size, 1)

            # src_key_padding_mask = mapped_input_gene_ids.eq(vocab[pad_token])
            src_key_padding_mask = torch.zeros_like(
                input_values, dtype=torch.bool, device=device
            )

        with torch.cuda.amp.autocast(enabled=amp):
            output_dict = model(
                mapped_input_gene_ids,
                input_values,
                input_pert_flags,
                src_key_padding_mask=src_key_padding_mask,
                CLS=CLS,
                CCE=CCE,
                MVC=MVC,
                ECS=ECS,
            )
            output_values = output_dict["mlm_output"]

            masked_positions = torch.ones_like(
                input_values, dtype=torch.bool
            )  # Use all
            loss = loss_mse = criterion(output_values, target_values, masked_positions)

        model.zero_grad()
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        with warnings.catch_warnings(record=True) as w:
            warnings.filterwarnings("always")
            torch.nn.utils.clip_grad_norm_(
                model.parameters(),
                1.0,
                error_if_nonfinite=False if scaler.is_enabled() else True,
            )
            if len(w) > 0:
                logger.warning(
                    f"Found infinite gradient. This may be caused by the gradient "
                    f"scaler. The current scale is {scaler.get_scale()}. This warning "
                    "can be ignored if no longer occurs after autoscaling of the scaler."
                )
        scaler.step(optimizer)
        scaler.update()

        # torch.cuda.empty_cache()

        total_loss += loss.item()
        total_mse += loss_mse.item()
        if batch % log_interval == 0 and batch > 0:
            lr = scheduler.get_last_lr()[0]
            ms_per_batch = (time.time() - start_time) * 1000 / log_interval
            cur_loss = total_loss / log_interval
            cur_mse = total_mse / log_interval
            # ppl = math.exp(cur_loss)
            logger.info(
                f"| epoch {epoch:3d} | {batch:3d}/{num_batches:3d} batches | "
                f"lr {lr:05.4f} | ms/batch {ms_per_batch:5.2f} | "
                f"loss {cur_loss:5.2f} | mse {cur_mse:5.2f} |"
            )
            total_loss = 0
            total_mse = 0
            start_time = time.time()


def eval_perturb(
        loader: DataLoader, model: TransformerGenerator, device: torch.device
) -> Dict:
    """
    Run model in inference mode using a given data loader
    """

    model.eval()
    model.to(device)
    pert_cat = []
    pred = []
    truth = []
    pred_de = []
    truth_de = []
    results = {}
    logvar = []

    for itr, batch in enumerate(loader):
        batch.to(device)
        pert_cat.extend(batch.pert)

        with torch.no_grad():
            p = model.pred_perturb(
                batch,
                include_zero_gene=include_zero_gene,
                gene_ids=gene_ids,
            )
            t = batch.y
            pred.extend(p.cpu())
            truth.extend(t.cpu())

            # Differentially expressed genes
            for itr, de_idx in enumerate(batch.de_idx):
                pred_de.append(p[itr, de_idx])
                truth_de.append(t[itr, de_idx])

    # all genes
    results["pert_cat"] = np.array(pert_cat)
    pred = torch.stack(pred)
    truth = torch.stack(truth)
    results["pred"] = pred.detach().cpu().numpy().astype(np.float64)
    results["truth"] = truth.detach().cpu().numpy().astype(np.float64)

    pred_de = torch.stack(pred_de)
    truth_de = torch.stack(truth_de)
    results["pred_de"] = pred_de.detach().cpu().numpy().astype(np.float64)
    results["truth_de"] = truth_de.detach().cpu().numpy().astype(np.float64)

    return results

# %%
best_val_loss = float("inf")
best_val_corr = 0
best_model = None
patience = 0

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train_loader = pert_data.dataloader["train_loader"]
    valid_loader = pert_data.dataloader["val_loader"]

    train(
        model,
        train_loader,
    )

    val_res = eval_perturb(valid_loader, model, device)
    val_metrics = compute_perturbation_metrics(
        val_res, pert_data.adata[pert_data.adata.obs["condition"] == "ctrl"]
    )
    logger.info(f"val_metrics at epoch {epoch}: ")
    logger.info(val_metrics)

    elapsed = time.time() - epoch_start_time
    logger.info(f"| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | ")

    val_score = val_metrics["pearson"]
    if val_score > best_val_corr:
        best_val_corr = val_score
        best_model = copy.deepcopy(model)
        logger.info(f"Best model with score {val_score:5.4f}")
        patience = 0
    else:
        patience += 1
        if patience >= early_stop:
            logger.info(f"Early stop at epoch {epoch}")
            break


    scheduler.step()
# Out:
# scGPT - INFO - | epoch   1 | 100/2717 batches | lr 0.0001 | ms/batch 376.10 | loss  0.10 | mse  0.10 |
# scGPT - INFO - | epoch   1 | 200/2717 batches | lr 0.0001 | ms/batch 373.78 | loss  0.09 | mse  0.09 |
# scGPT - INFO - | epoch   1 | 300/2717 batches | lr 0.0001 | ms/batch 374.26 | loss  0.09 | mse  0.09 |
# scGPT - INFO - | epoch   1 | 400/2717 batches | lr 0.0001 | ms/batch 374.80 | loss  0.09 | mse  0.09 |
# scGPT - INFO - | epoch   1 | 500/2717 batches | lr 0.0001 | ms/batch 374.89 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 600/2717 batches | lr 0.0001 | ms/batch 374.82 | loss  0.09 | mse  0.09 |
# scGPT - INFO - | epoch   1 | 700/2717 batches | lr 0.0001 | ms/batch 375.02 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 800/2717 batches | lr 0.0001 | ms/batch 374.95 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 900/2717 batches | lr 0.0001 | ms/batch 375.11 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1000/2717 batches | lr 0.0001 | ms/batch 374.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1100/2717 batches | lr 0.0001 | ms/batch 375.14 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1200/2717 batches | lr 0.0001 | ms/batch 374.95 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1300/2717 batches | lr 0.0001 | ms/batch 375.03 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1400/2717 batches | lr 0.0001 | ms/batch 375.03 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1500/2717 batches | lr 0.0001 | ms/batch 375.10 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1600/2717 batches | lr 0.0001 | ms/batch 374.95 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1700/2717 batches | lr 0.0001 | ms/batch 375.05 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1800/2717 batches | lr 0.0001 | ms/batch 375.13 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 1900/2717 batches | lr 0.0001 | ms/batch 374.91 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 2000/2717 batches | lr 0.0001 | ms/batch 375.10 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 2100/2717 batches | lr 0.0001 | ms/batch 375.09 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 2200/2717 batches | lr 0.0001 | ms/batch 375.02 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 2300/2717 batches | lr 0.0001 | ms/batch 375.11 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 2400/2717 batches | lr 0.0001 | ms/batch 375.18 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 2500/2717 batches | lr 0.0001 | ms/batch 375.22 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 2600/2717 batches | lr 0.0001 | ms/batch 375.08 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   1 | 2700/2717 batches | lr 0.0001 | ms/batch 375.09 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 1:
# scGPT - INFO - {'pearson': 0.988928282912539, 'pearson_de': 0.9239845448407589, 'pearson_delta': 0.6566761643314599, 'pearson_de_delta': 0.7939430970508886}
# scGPT - INFO - | end of epoch   1 | time: 1232.86s |
# scGPT - INFO - Best model with score 0.9889
# scGPT - INFO - | epoch   2 | 100/2717 batches | lr 0.0001 | ms/batch 379.59 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 200/2717 batches | lr 0.0001 | ms/batch 375.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 300/2717 batches | lr 0.0001 | ms/batch 375.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 400/2717 batches | lr 0.0001 | ms/batch 375.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 500/2717 batches | lr 0.0001 | ms/batch 375.77 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 600/2717 batches | lr 0.0001 | ms/batch 375.66 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 700/2717 batches | lr 0.0001 | ms/batch 375.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 800/2717 batches | lr 0.0001 | ms/batch 375.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 900/2717 batches | lr 0.0001 | ms/batch 375.75 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1000/2717 batches | lr 0.0001 | ms/batch 375.77 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1100/2717 batches | lr 0.0001 | ms/batch 375.80 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1200/2717 batches | lr 0.0001 | ms/batch 375.77 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1300/2717 batches | lr 0.0001 | ms/batch 375.87 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1400/2717 batches | lr 0.0001 | ms/batch 375.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1500/2717 batches | lr 0.0001 | ms/batch 375.67 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1600/2717 batches | lr 0.0001 | ms/batch 375.89 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1700/2717 batches | lr 0.0001 | ms/batch 375.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1800/2717 batches | lr 0.0001 | ms/batch 375.87 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 1900/2717 batches | lr 0.0001 | ms/batch 375.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 2000/2717 batches | lr 0.0001 | ms/batch 375.93 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 2100/2717 batches | lr 0.0001 | ms/batch 375.95 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 2200/2717 batches | lr 0.0001 | ms/batch 375.80 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 2300/2717 batches | lr 0.0001 | ms/batch 375.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 2400/2717 batches | lr 0.0001 | ms/batch 376.07 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 2500/2717 batches | lr 0.0001 | ms/batch 376.30 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 2600/2717 batches | lr 0.0001 | ms/batch 376.23 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   2 | 2700/2717 batches | lr 0.0001 | ms/batch 376.15 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 2:
# scGPT - INFO - {'pearson': 0.9883892282156109, 'pearson_de': 0.9228837941882807, 'pearson_delta': 0.6407692844158918, 'pearson_de_delta': 0.7873407445021845}
# scGPT - INFO - | end of epoch   2 | time: 1235.62s |
# scGPT - INFO - | epoch   3 | 100/2717 batches | lr 0.0001 | ms/batch 379.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 200/2717 batches | lr 0.0001 | ms/batch 375.67 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 300/2717 batches | lr 0.0001 | ms/batch 375.93 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 400/2717 batches | lr 0.0001 | ms/batch 375.91 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 500/2717 batches | lr 0.0001 | ms/batch 375.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 600/2717 batches | lr 0.0001 | ms/batch 375.90 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 700/2717 batches | lr 0.0001 | ms/batch 375.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 800/2717 batches | lr 0.0001 | ms/batch 375.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 900/2717 batches | lr 0.0001 | ms/batch 375.89 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1000/2717 batches | lr 0.0001 | ms/batch 375.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1100/2717 batches | lr 0.0001 | ms/batch 375.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1200/2717 batches | lr 0.0001 | ms/batch 375.90 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1300/2717 batches | lr 0.0001 | ms/batch 375.91 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1400/2717 batches | lr 0.0001 | ms/batch 375.74 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1500/2717 batches | lr 0.0001 | ms/batch 375.93 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1600/2717 batches | lr 0.0001 | ms/batch 375.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1700/2717 batches | lr 0.0001 | ms/batch 375.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1800/2717 batches | lr 0.0001 | ms/batch 375.86 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 1900/2717 batches | lr 0.0001 | ms/batch 375.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 2000/2717 batches | lr 0.0001 | ms/batch 375.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 2100/2717 batches | lr 0.0001 | ms/batch 375.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 2200/2717 batches | lr 0.0001 | ms/batch 375.93 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 2300/2717 batches | lr 0.0001 | ms/batch 375.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 2400/2717 batches | lr 0.0001 | ms/batch 375.86 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 2500/2717 batches | lr 0.0001 | ms/batch 375.91 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 2600/2717 batches | lr 0.0001 | ms/batch 375.95 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   3 | 2700/2717 batches | lr 0.0001 | ms/batch 375.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 3:
# scGPT - INFO - {'pearson': 0.9883316374490553, 'pearson_de': 0.9230213465453687, 'pearson_delta': 0.6403825972284721, 'pearson_de_delta': 0.7456864909247073}
# scGPT - INFO - | end of epoch   3 | time: 1235.61s |
# scGPT - INFO - | epoch   4 | 100/2717 batches | lr 0.0001 | ms/batch 379.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 200/2717 batches | lr 0.0001 | ms/batch 375.98 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 300/2717 batches | lr 0.0001 | ms/batch 375.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 400/2717 batches | lr 0.0001 | ms/batch 375.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 500/2717 batches | lr 0.0001 | ms/batch 375.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 600/2717 batches | lr 0.0001 | ms/batch 375.90 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 700/2717 batches | lr 0.0001 | ms/batch 375.78 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 800/2717 batches | lr 0.0001 | ms/batch 375.87 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 900/2717 batches | lr 0.0001 | ms/batch 375.97 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1000/2717 batches | lr 0.0001 | ms/batch 375.07 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1100/2717 batches | lr 0.0001 | ms/batch 374.29 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1200/2717 batches | lr 0.0001 | ms/batch 374.13 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1300/2717 batches | lr 0.0001 | ms/batch 374.77 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1400/2717 batches | lr 0.0001 | ms/batch 374.63 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1500/2717 batches | lr 0.0001 | ms/batch 374.61 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1600/2717 batches | lr 0.0001 | ms/batch 374.60 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1700/2717 batches | lr 0.0001 | ms/batch 374.69 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1800/2717 batches | lr 0.0001 | ms/batch 374.70 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 1900/2717 batches | lr 0.0001 | ms/batch 374.60 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 2000/2717 batches | lr 0.0001 | ms/batch 374.65 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 2100/2717 batches | lr 0.0001 | ms/batch 374.64 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 2200/2717 batches | lr 0.0001 | ms/batch 374.75 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 2300/2717 batches | lr 0.0001 | ms/batch 374.69 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 2400/2717 batches | lr 0.0001 | ms/batch 374.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 2500/2717 batches | lr 0.0001 | ms/batch 374.75 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 2600/2717 batches | lr 0.0001 | ms/batch 374.67 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   4 | 2700/2717 batches | lr 0.0001 | ms/batch 374.60 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 4:
# scGPT - INFO - {'pearson': 0.9889060083677857, 'pearson_de': 0.9498553450989766, 'pearson_delta': 0.6423398250589313, 'pearson_de_delta': 0.8352155964907867}
# scGPT - INFO - | end of epoch   4 | time: 1233.33s |
# scGPT - INFO - | epoch   5 | 100/2717 batches | lr 0.0001 | ms/batch 378.49 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 200/2717 batches | lr 0.0001 | ms/batch 374.64 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 300/2717 batches | lr 0.0001 | ms/batch 374.59 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 400/2717 batches | lr 0.0001 | ms/batch 374.68 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 500/2717 batches | lr 0.0001 | ms/batch 374.55 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 600/2717 batches | lr 0.0001 | ms/batch 374.70 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 700/2717 batches | lr 0.0001 | ms/batch 374.61 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 800/2717 batches | lr 0.0001 | ms/batch 374.71 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 900/2717 batches | lr 0.0001 | ms/batch 374.67 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1000/2717 batches | lr 0.0001 | ms/batch 374.57 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1100/2717 batches | lr 0.0001 | ms/batch 374.54 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1200/2717 batches | lr 0.0001 | ms/batch 374.54 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1300/2717 batches | lr 0.0001 | ms/batch 374.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1400/2717 batches | lr 0.0001 | ms/batch 374.73 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1500/2717 batches | lr 0.0001 | ms/batch 374.62 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1600/2717 batches | lr 0.0001 | ms/batch 374.74 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1700/2717 batches | lr 0.0001 | ms/batch 374.57 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1800/2717 batches | lr 0.0001 | ms/batch 374.72 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 1900/2717 batches | lr 0.0001 | ms/batch 374.50 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 2000/2717 batches | lr 0.0001 | ms/batch 374.53 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 2100/2717 batches | lr 0.0001 | ms/batch 374.54 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 2200/2717 batches | lr 0.0001 | ms/batch 374.53 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 2300/2717 batches | lr 0.0001 | ms/batch 374.65 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 2400/2717 batches | lr 0.0001 | ms/batch 374.55 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 2500/2717 batches | lr 0.0001 | ms/batch 374.50 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 2600/2717 batches | lr 0.0001 | ms/batch 374.56 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   5 | 2700/2717 batches | lr 0.0001 | ms/batch 374.60 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 5:
# scGPT - INFO - {'pearson': 0.9891762836902397, 'pearson_de': 0.9503943837609955, 'pearson_delta': 0.6696830034363694, 'pearson_de_delta': 0.8703848279014078}
# scGPT - INFO - | end of epoch   5 | time: 1232.14s |
# scGPT - INFO - Best model with score 0.9892
# scGPT - INFO - | epoch   6 | 100/2717 batches | lr 0.0001 | ms/batch 378.46 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 200/2717 batches | lr 0.0001 | ms/batch 374.57 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 300/2717 batches | lr 0.0001 | ms/batch 374.54 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 400/2717 batches | lr 0.0001 | ms/batch 374.47 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 500/2717 batches | lr 0.0001 | ms/batch 374.60 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 600/2717 batches | lr 0.0001 | ms/batch 374.53 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 700/2717 batches | lr 0.0001 | ms/batch 374.46 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 800/2717 batches | lr 0.0001 | ms/batch 374.48 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 900/2717 batches | lr 0.0001 | ms/batch 374.39 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1000/2717 batches | lr 0.0001 | ms/batch 374.49 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1100/2717 batches | lr 0.0001 | ms/batch 374.25 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1200/2717 batches | lr 0.0001 | ms/batch 374.41 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1300/2717 batches | lr 0.0001 | ms/batch 374.25 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1400/2717 batches | lr 0.0001 | ms/batch 374.31 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1500/2717 batches | lr 0.0001 | ms/batch 374.38 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1600/2717 batches | lr 0.0001 | ms/batch 374.33 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1700/2717 batches | lr 0.0001 | ms/batch 374.43 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1800/2717 batches | lr 0.0001 | ms/batch 374.33 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 1900/2717 batches | lr 0.0001 | ms/batch 374.26 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 2000/2717 batches | lr 0.0001 | ms/batch 374.09 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 2100/2717 batches | lr 0.0001 | ms/batch 374.37 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 2200/2717 batches | lr 0.0001 | ms/batch 374.26 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 2300/2717 batches | lr 0.0001 | ms/batch 374.25 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 2400/2717 batches | lr 0.0001 | ms/batch 374.22 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 2500/2717 batches | lr 0.0001 | ms/batch 374.26 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 2600/2717 batches | lr 0.0001 | ms/batch 374.19 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   6 | 2700/2717 batches | lr 0.0001 | ms/batch 374.16 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 6:
# scGPT - INFO - {'pearson': 0.9899249724379502, 'pearson_de': 0.9589221136787655, 'pearson_delta': 0.6731008534771419, 'pearson_de_delta': 0.894505718027814}
# scGPT - INFO - | end of epoch   6 | time: 1231.46s |
# scGPT - INFO - Best model with score 0.9899
# scGPT - INFO - | epoch   7 | 100/2717 batches | lr 0.0001 | ms/batch 378.09 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 200/2717 batches | lr 0.0001 | ms/batch 374.25 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 300/2717 batches | lr 0.0001 | ms/batch 374.19 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 400/2717 batches | lr 0.0001 | ms/batch 374.26 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 500/2717 batches | lr 0.0001 | ms/batch 374.22 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 600/2717 batches | lr 0.0001 | ms/batch 374.39 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 700/2717 batches | lr 0.0001 | ms/batch 374.14 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 800/2717 batches | lr 0.0001 | ms/batch 374.31 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 900/2717 batches | lr 0.0001 | ms/batch 374.19 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1000/2717 batches | lr 0.0001 | ms/batch 374.21 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1100/2717 batches | lr 0.0001 | ms/batch 374.28 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1200/2717 batches | lr 0.0001 | ms/batch 374.23 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1300/2717 batches | lr 0.0001 | ms/batch 374.31 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1400/2717 batches | lr 0.0001 | ms/batch 374.14 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1500/2717 batches | lr 0.0001 | ms/batch 374.29 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1600/2717 batches | lr 0.0001 | ms/batch 374.05 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1700/2717 batches | lr 0.0001 | ms/batch 374.23 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1800/2717 batches | lr 0.0001 | ms/batch 373.97 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 1900/2717 batches | lr 0.0001 | ms/batch 374.14 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 2000/2717 batches | lr 0.0001 | ms/batch 374.09 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 2100/2717 batches | lr 0.0001 | ms/batch 374.12 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 2200/2717 batches | lr 0.0001 | ms/batch 374.17 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 2300/2717 batches | lr 0.0001 | ms/batch 374.10 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 2400/2717 batches | lr 0.0001 | ms/batch 374.04 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 2500/2717 batches | lr 0.0001 | ms/batch 374.20 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 2600/2717 batches | lr 0.0001 | ms/batch 374.10 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   7 | 2700/2717 batches | lr 0.0001 | ms/batch 374.03 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 7:
# scGPT - INFO - {'pearson': 0.9902779884130041, 'pearson_de': 0.9540812660915197, 'pearson_delta': 0.6632927191550877, 'pearson_de_delta': 0.8736354631963031}
# scGPT - INFO - | end of epoch   7 | time: 1230.93s |
# scGPT - INFO - Best model with score 0.9903
# scGPT - INFO - | epoch   8 | 100/2717 batches | lr 0.0000 | ms/batch 377.74 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 200/2717 batches | lr 0.0000 | ms/batch 374.02 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 300/2717 batches | lr 0.0000 | ms/batch 373.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 400/2717 batches | lr 0.0000 | ms/batch 373.97 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 500/2717 batches | lr 0.0000 | ms/batch 373.92 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 600/2717 batches | lr 0.0000 | ms/batch 373.97 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 700/2717 batches | lr 0.0000 | ms/batch 373.90 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 800/2717 batches | lr 0.0000 | ms/batch 374.03 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 900/2717 batches | lr 0.0000 | ms/batch 374.08 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1000/2717 batches | lr 0.0000 | ms/batch 373.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1100/2717 batches | lr 0.0000 | ms/batch 373.98 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1200/2717 batches | lr 0.0000 | ms/batch 374.04 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1300/2717 batches | lr 0.0000 | ms/batch 374.01 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1400/2717 batches | lr 0.0000 | ms/batch 373.86 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1500/2717 batches | lr 0.0000 | ms/batch 373.89 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1600/2717 batches | lr 0.0000 | ms/batch 373.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1700/2717 batches | lr 0.0000 | ms/batch 373.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1800/2717 batches | lr 0.0000 | ms/batch 373.97 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 1900/2717 batches | lr 0.0000 | ms/batch 373.80 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 2000/2717 batches | lr 0.0000 | ms/batch 373.89 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 2100/2717 batches | lr 0.0000 | ms/batch 373.90 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 2200/2717 batches | lr 0.0000 | ms/batch 373.90 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 2300/2717 batches | lr 0.0000 | ms/batch 373.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 2400/2717 batches | lr 0.0000 | ms/batch 373.96 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 2500/2717 batches | lr 0.0000 | ms/batch 373.93 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 2600/2717 batches | lr 0.0000 | ms/batch 373.92 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   8 | 2700/2717 batches | lr 0.0000 | ms/batch 373.97 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 8:
# scGPT - INFO - {'pearson': 0.9896974560558631, 'pearson_de': 0.950551398715466, 'pearson_delta': 0.6583016025630075, 'pearson_de_delta': 0.8223837831548882}
# scGPT - INFO - | end of epoch   8 | time: 1230.25s |
# scGPT - INFO - | epoch   9 | 100/2717 batches | lr 0.0000 | ms/batch 377.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 200/2717 batches | lr 0.0000 | ms/batch 374.05 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 300/2717 batches | lr 0.0000 | ms/batch 373.91 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 400/2717 batches | lr 0.0000 | ms/batch 374.00 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 500/2717 batches | lr 0.0000 | ms/batch 373.91 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 600/2717 batches | lr 0.0000 | ms/batch 373.93 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 700/2717 batches | lr 0.0000 | ms/batch 374.03 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 800/2717 batches | lr 0.0000 | ms/batch 373.92 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 900/2717 batches | lr 0.0000 | ms/batch 374.00 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1000/2717 batches | lr 0.0000 | ms/batch 373.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1100/2717 batches | lr 0.0000 | ms/batch 373.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1200/2717 batches | lr 0.0000 | ms/batch 373.93 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1300/2717 batches | lr 0.0000 | ms/batch 373.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1400/2717 batches | lr 0.0000 | ms/batch 374.03 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1500/2717 batches | lr 0.0000 | ms/batch 373.74 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1600/2717 batches | lr 0.0000 | ms/batch 373.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1700/2717 batches | lr 0.0000 | ms/batch 373.95 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1800/2717 batches | lr 0.0000 | ms/batch 373.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 1900/2717 batches | lr 0.0000 | ms/batch 373.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 2000/2717 batches | lr 0.0000 | ms/batch 373.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 2100/2717 batches | lr 0.0000 | ms/batch 373.94 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 2200/2717 batches | lr 0.0000 | ms/batch 373.86 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 2300/2717 batches | lr 0.0000 | ms/batch 373.74 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 2400/2717 batches | lr 0.0000 | ms/batch 373.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 2500/2717 batches | lr 0.0000 | ms/batch 373.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 2600/2717 batches | lr 0.0000 | ms/batch 373.73 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch   9 | 2700/2717 batches | lr 0.0000 | ms/batch 373.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 9:
# scGPT - INFO - {'pearson': 0.9896965686830191, 'pearson_de': 0.9557576181413657, 'pearson_delta': 0.6796823315158882, 'pearson_de_delta': 0.8299023200975332}
# scGPT - INFO - | end of epoch   9 | time: 1230.08s |
# scGPT - INFO - | epoch  10 | 100/2717 batches | lr 0.0000 | ms/batch 377.62 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 200/2717 batches | lr 0.0000 | ms/batch 373.73 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 300/2717 batches | lr 0.0000 | ms/batch 373.90 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 400/2717 batches | lr 0.0000 | ms/batch 373.68 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 500/2717 batches | lr 0.0000 | ms/batch 373.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 600/2717 batches | lr 0.0000 | ms/batch 373.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 700/2717 batches | lr 0.0000 | ms/batch 373.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 800/2717 batches | lr 0.0000 | ms/batch 373.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 900/2717 batches | lr 0.0000 | ms/batch 373.73 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1000/2717 batches | lr 0.0000 | ms/batch 373.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1100/2717 batches | lr 0.0000 | ms/batch 373.73 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1200/2717 batches | lr 0.0000 | ms/batch 373.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1300/2717 batches | lr 0.0000 | ms/batch 373.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1400/2717 batches | lr 0.0000 | ms/batch 373.66 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1500/2717 batches | lr 0.0000 | ms/batch 373.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1600/2717 batches | lr 0.0000 | ms/batch 373.78 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1700/2717 batches | lr 0.0000 | ms/batch 373.71 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1800/2717 batches | lr 0.0000 | ms/batch 373.72 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 1900/2717 batches | lr 0.0000 | ms/batch 373.73 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 2000/2717 batches | lr 0.0000 | ms/batch 373.78 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 2100/2717 batches | lr 0.0000 | ms/batch 373.64 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 2200/2717 batches | lr 0.0000 | ms/batch 373.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 2300/2717 batches | lr 0.0000 | ms/batch 373.69 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 2400/2717 batches | lr 0.0000 | ms/batch 373.51 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 2500/2717 batches | lr 0.0000 | ms/batch 373.59 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 2600/2717 batches | lr 0.0000 | ms/batch 373.55 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  10 | 2700/2717 batches | lr 0.0000 | ms/batch 373.50 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 10:
# scGPT - INFO - {'pearson': 0.9896682747298826, 'pearson_de': 0.9522898371726198, 'pearson_delta': 0.6857384840404278, 'pearson_de_delta': 0.8398109970413107}
# scGPT - INFO - | end of epoch  10 | time: 1229.65s |
# scGPT - INFO - | epoch  11 | 100/2717 batches | lr 0.0000 | ms/batch 377.39 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 200/2717 batches | lr 0.0000 | ms/batch 373.41 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 300/2717 batches | lr 0.0000 | ms/batch 373.27 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 400/2717 batches | lr 0.0000 | ms/batch 373.53 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 500/2717 batches | lr 0.0000 | ms/batch 373.38 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 600/2717 batches | lr 0.0000 | ms/batch 373.37 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 700/2717 batches | lr 0.0000 | ms/batch 373.37 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 800/2717 batches | lr 0.0000 | ms/batch 373.30 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 900/2717 batches | lr 0.0000 | ms/batch 373.37 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1000/2717 batches | lr 0.0000 | ms/batch 373.40 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1100/2717 batches | lr 0.0000 | ms/batch 373.45 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1200/2717 batches | lr 0.0000 | ms/batch 373.35 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1300/2717 batches | lr 0.0000 | ms/batch 373.41 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1400/2717 batches | lr 0.0000 | ms/batch 373.30 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1500/2717 batches | lr 0.0000 | ms/batch 373.26 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1600/2717 batches | lr 0.0000 | ms/batch 373.23 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1700/2717 batches | lr 0.0000 | ms/batch 373.28 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1800/2717 batches | lr 0.0000 | ms/batch 373.27 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 1900/2717 batches | lr 0.0000 | ms/batch 373.29 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 2000/2717 batches | lr 0.0000 | ms/batch 373.19 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 2100/2717 batches | lr 0.0000 | ms/batch 373.25 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 2200/2717 batches | lr 0.0000 | ms/batch 373.21 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 2300/2717 batches | lr 0.0000 | ms/batch 373.13 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 2400/2717 batches | lr 0.0000 | ms/batch 373.30 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 2500/2717 batches | lr 0.0000 | ms/batch 373.12 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 2600/2717 batches | lr 0.0000 | ms/batch 373.20 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  11 | 2700/2717 batches | lr 0.0000 | ms/batch 373.22 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 11:
# scGPT - INFO - {'pearson': 0.990446465931762, 'pearson_de': 0.9556106249668715, 'pearson_delta': 0.694194138319488, 'pearson_de_delta': 0.8620032921915491}
# scGPT - INFO - | end of epoch  11 | time: 1228.49s |
# scGPT - INFO - Best model with score 0.9904
# scGPT - INFO - | epoch  12 | 100/2717 batches | lr 0.0000 | ms/batch 377.18 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 200/2717 batches | lr 0.0000 | ms/batch 373.14 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 300/2717 batches | lr 0.0000 | ms/batch 373.19 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 400/2717 batches | lr 0.0000 | ms/batch 373.14 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 500/2717 batches | lr 0.0000 | ms/batch 373.13 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 600/2717 batches | lr 0.0000 | ms/batch 373.18 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 700/2717 batches | lr 0.0000 | ms/batch 373.16 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 800/2717 batches | lr 0.0000 | ms/batch 373.11 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 900/2717 batches | lr 0.0000 | ms/batch 373.20 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1000/2717 batches | lr 0.0000 | ms/batch 373.13 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1100/2717 batches | lr 0.0000 | ms/batch 373.12 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1200/2717 batches | lr 0.0000 | ms/batch 373.10 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1300/2717 batches | lr 0.0000 | ms/batch 373.13 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1400/2717 batches | lr 0.0000 | ms/batch 373.11 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1500/2717 batches | lr 0.0000 | ms/batch 373.11 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1600/2717 batches | lr 0.0000 | ms/batch 373.12 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1700/2717 batches | lr 0.0000 | ms/batch 373.13 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1800/2717 batches | lr 0.0000 | ms/batch 373.12 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 1900/2717 batches | lr 0.0000 | ms/batch 373.11 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 2000/2717 batches | lr 0.0000 | ms/batch 373.09 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 2100/2717 batches | lr 0.0000 | ms/batch 372.96 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 2200/2717 batches | lr 0.0000 | ms/batch 372.96 | loss  0.07 | mse  0.07 |
# scGPT - INFO - | epoch  12 | 2300/2717 batches | lr 0.0000 | ms/batch 372.93 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 2400/2717 batches | lr 0.0000 | ms/batch 373.08 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 2500/2717 batches | lr 0.0000 | ms/batch 373.10 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 2600/2717 batches | lr 0.0000 | ms/batch 372.97 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  12 | 2700/2717 batches | lr 0.0000 | ms/batch 372.96 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 12:
# scGPT - INFO - {'pearson': 0.9900466370723453, 'pearson_de': 0.9517744907784154, 'pearson_delta': 0.6927698756747355, 'pearson_de_delta': 0.8172925310798094}
# scGPT - INFO - | end of epoch  12 | time: 1227.90s |
# scGPT - INFO - | epoch  13 | 100/2717 batches | lr 0.0000 | ms/batch 376.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 200/2717 batches | lr 0.0000 | ms/batch 372.96 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 300/2717 batches | lr 0.0000 | ms/batch 373.03 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 400/2717 batches | lr 0.0000 | ms/batch 373.01 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 500/2717 batches | lr 0.0000 | ms/batch 372.96 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 600/2717 batches | lr 0.0000 | ms/batch 372.80 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 700/2717 batches | lr 0.0000 | ms/batch 372.90 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 800/2717 batches | lr 0.0000 | ms/batch 372.92 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 900/2717 batches | lr 0.0000 | ms/batch 372.89 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1000/2717 batches | lr 0.0000 | ms/batch 372.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1100/2717 batches | lr 0.0000 | ms/batch 372.91 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1200/2717 batches | lr 0.0000 | ms/batch 372.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1300/2717 batches | lr 0.0000 | ms/batch 372.95 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1400/2717 batches | lr 0.0000 | ms/batch 372.87 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1500/2717 batches | lr 0.0000 | ms/batch 372.86 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1600/2717 batches | lr 0.0000 | ms/batch 372.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1700/2717 batches | lr 0.0000 | ms/batch 372.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1800/2717 batches | lr 0.0000 | ms/batch 372.91 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 1900/2717 batches | lr 0.0000 | ms/batch 372.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 2000/2717 batches | lr 0.0000 | ms/batch 372.89 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 2100/2717 batches | lr 0.0000 | ms/batch 372.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 2200/2717 batches | lr 0.0000 | ms/batch 372.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 2300/2717 batches | lr 0.0000 | ms/batch 372.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 2400/2717 batches | lr 0.0000 | ms/batch 372.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 2500/2717 batches | lr 0.0000 | ms/batch 372.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 2600/2717 batches | lr 0.0000 | ms/batch 372.70 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  13 | 2700/2717 batches | lr 0.0000 | ms/batch 372.86 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 13:
# scGPT - INFO - {'pearson': 0.9896657253605995, 'pearson_de': 0.9530755064770758, 'pearson_delta': 0.6838020721045645, 'pearson_de_delta': 0.8568973126454306}
# scGPT - INFO - | end of epoch  13 | time: 1227.24s |
# scGPT - INFO - | epoch  14 | 100/2717 batches | lr 0.0000 | ms/batch 376.61 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 200/2717 batches | lr 0.0000 | ms/batch 372.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 300/2717 batches | lr 0.0000 | ms/batch 372.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 400/2717 batches | lr 0.0000 | ms/batch 372.73 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 500/2717 batches | lr 0.0000 | ms/batch 372.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 600/2717 batches | lr 0.0000 | ms/batch 372.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 700/2717 batches | lr 0.0000 | ms/batch 372.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 800/2717 batches | lr 0.0000 | ms/batch 372.78 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 900/2717 batches | lr 0.0000 | ms/batch 372.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1000/2717 batches | lr 0.0000 | ms/batch 372.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1100/2717 batches | lr 0.0000 | ms/batch 372.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1200/2717 batches | lr 0.0000 | ms/batch 372.87 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1300/2717 batches | lr 0.0000 | ms/batch 372.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1400/2717 batches | lr 0.0000 | ms/batch 372.80 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1500/2717 batches | lr 0.0000 | ms/batch 372.87 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1600/2717 batches | lr 0.0000 | ms/batch 372.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1700/2717 batches | lr 0.0000 | ms/batch 372.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1800/2717 batches | lr 0.0000 | ms/batch 372.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 1900/2717 batches | lr 0.0000 | ms/batch 372.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 2000/2717 batches | lr 0.0000 | ms/batch 372.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 2100/2717 batches | lr 0.0000 | ms/batch 372.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 2200/2717 batches | lr 0.0000 | ms/batch 372.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 2300/2717 batches | lr 0.0000 | ms/batch 372.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 2400/2717 batches | lr 0.0000 | ms/batch 372.77 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 2500/2717 batches | lr 0.0000 | ms/batch 372.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 2600/2717 batches | lr 0.0000 | ms/batch 372.84 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  14 | 2700/2717 batches | lr 0.0000 | ms/batch 372.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 14:
# scGPT - INFO - {'pearson': 0.9903395326327923, 'pearson_de': 0.9539253802545865, 'pearson_delta': 0.7012514706238616, 'pearson_de_delta': 0.8513838593248595}
# scGPT - INFO - | end of epoch  14 | time: 1227.07s |
# scGPT - INFO - | epoch  15 | 100/2717 batches | lr 0.0000 | ms/batch 376.65 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 200/2717 batches | lr 0.0000 | ms/batch 372.80 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 300/2717 batches | lr 0.0000 | ms/batch 372.76 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 400/2717 batches | lr 0.0000 | ms/batch 372.80 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 500/2717 batches | lr 0.0000 | ms/batch 372.89 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 600/2717 batches | lr 0.0000 | ms/batch 372.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 700/2717 batches | lr 0.0000 | ms/batch 372.70 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 800/2717 batches | lr 0.0000 | ms/batch 372.88 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 900/2717 batches | lr 0.0000 | ms/batch 372.73 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1000/2717 batches | lr 0.0000 | ms/batch 372.86 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1100/2717 batches | lr 0.0000 | ms/batch 372.80 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1200/2717 batches | lr 0.0000 | ms/batch 372.85 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1300/2717 batches | lr 0.0000 | ms/batch 372.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1400/2717 batches | lr 0.0000 | ms/batch 372.68 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1500/2717 batches | lr 0.0000 | ms/batch 372.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1600/2717 batches | lr 0.0000 | ms/batch 372.75 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1700/2717 batches | lr 0.0000 | ms/batch 372.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1800/2717 batches | lr 0.0000 | ms/batch 372.82 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 1900/2717 batches | lr 0.0000 | ms/batch 372.89 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 2000/2717 batches | lr 0.0000 | ms/batch 372.91 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 2100/2717 batches | lr 0.0000 | ms/batch 372.90 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 2200/2717 batches | lr 0.0000 | ms/batch 372.86 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 2300/2717 batches | lr 0.0000 | ms/batch 372.79 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 2400/2717 batches | lr 0.0000 | ms/batch 372.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 2500/2717 batches | lr 0.0000 | ms/batch 372.81 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 2600/2717 batches | lr 0.0000 | ms/batch 372.83 | loss  0.08 | mse  0.08 |
# scGPT - INFO - | epoch  15 | 2700/2717 batches | lr 0.0000 | ms/batch 372.73 | loss  0.08 | mse  0.08 |
# scGPT - INFO - val_metrics at epoch 15:
# scGPT - INFO - {'pearson': 0.9905320215080861, 'pearson_de': 0.9545063029904951, 'pearson_delta': 0.7044509137157374, 'pearson_de_delta': 0.854253662356417}
# scGPT - INFO - | end of epoch  15 | time: 1227.09s |
# scGPT - INFO - Best model with score 0.9905

# %%
torch.save(best_model.state_dict(), save_dir / "best_model.pt")

# %%
def predict(
        model: TransformerGenerator, pert_list: List[str], pool_size: Optional[int] = None
) -> Dict:
    """
    Predict the gene expression values for the given perturbations.

    Args:
        model (:class:`torch.nn.Module`): The model to use for prediction.
        pert_list (:obj:`List[str]`): The list of perturbations to predict.
        pool_size (:obj:`int`, optional): For each perturbation, use this number
            of cells in the control and predict their perturbation results. Report
            the stats of these predictions. If `None`, use all control cells.
    """
    adata = pert_data.adata
    ctrl_adata = adata[adata.obs["condition"] == "ctrl"]
    if pool_size is None:
        pool_size = len(ctrl_adata.obs)
    gene_list = pert_data.gene_names.values.tolist()
    for pert in pert_list:
        for i in pert:
            if i not in gene_list:
                raise ValueError(
                    "The gene is not in the perturbation graph. Please select from GEARS.gene_list!"
                )

    model.eval()
    device = next(model.parameters()).device
    with torch.no_grad():
        results_pred = {}
        for pert in pert_list:
            cell_graphs = create_cell_graph_dataset_for_prediction(
                pert, ctrl_adata, gene_list, device, num_samples=pool_size
            )
            loader = DataLoader(cell_graphs, batch_size=eval_batch_size, shuffle=False)
            preds = []
            for batch_data in loader:
                pred_gene_values = model.pred_perturb(
                    batch_data, include_zero_gene, gene_ids=gene_ids, amp=amp
                )
                preds.append(pred_gene_values)
            preds = torch.cat(preds, dim=0)
            results_pred["_".join(pert)] = np.mean(preds.detach().cpu().numpy(), axis=0)

    return results_pred

# %%
def plot_perturbation(
        model: nn.Module, query: str, save_file: str = None, pool_size: int = None
) -> matplotlib.figure.Figure:
    import matplotlib.pyplot as plt
    import numpy as np
    import seaborn as sns

    sns.set_theme(style="ticks", rc={"axes.facecolor": (0, 0, 0, 0)}, font_scale=1.5)

    adata = pert_data.adata
    gene2idx = pert_data.node_map
    cond2name = dict(adata.obs[["condition", "condition_name"]].values)
    gene_raw2id = dict(zip(adata.var.index.values, adata.var.gene_name.values))

    de_idx = [
        gene2idx[gene_raw2id[i]]
        for i in adata.uns["top_non_dropout_de_20"][cond2name[query]]
    ]
    genes = [
        gene_raw2id[i] for i in adata.uns["top_non_dropout_de_20"][cond2name[query]]
    ]
    truth = adata[adata.obs.condition == query].X.toarray()[:, de_idx]
    if query.split("+")[1] == "ctrl":
        pred = predict(model, [[query.split("+")[0]]], pool_size=pool_size)
        pred = pred[query.split("+")[0]][de_idx]
    else:
        pred = predict(model, [query.split("+")], pool_size=pool_size)
        pred = pred["_".join(query.split("+"))][de_idx]
    ctrl_means = adata[adata.obs["condition"] == "ctrl"].to_df().mean()[de_idx].values

    pred = pred - ctrl_means
    truth = truth - ctrl_means

    fig, ax = plt.subplots(figsize=[16.5, 4.5])
    plt.title(query)
    plt.boxplot(truth, showfliers=False, medianprops=dict(linewidth=0))

    for i in range(pred.shape[0]):
        _ = plt.scatter(i + 1, pred[i], color="red")

    plt.axhline(0, linestyle="dashed", color="green")

    ax.xaxis.set_ticklabels(genes, rotation=90)

    plt.ylabel("Change in Gene Expression over Control", labelpad=10)
    plt.tick_params(axis="x", which="major", pad=5)
    plt.tick_params(axis="y", which="major", pad=5)
    sns.despine()

    if save_file:
        fig.savefig(save_file, bbox_inches="tight", transparent=False)

    return fig

# %%
# predict(best_model, [["FEV"], ["FEV", "SAMD11"]])
for p in perts_to_plot:
    plot_perturbation(best_model, p, pool_size=300, save_file=f"{save_dir}/{p}.png")

# %%
test_loader = pert_data.dataloader["test_loader"]
test_res = eval_perturb(test_loader, best_model, device)
# test_metrics, test_pert_res = compute_metrics(test_res)
test_metrics = compute_perturbation_metrics(
    test_res, pert_data.adata[pert_data.adata.obs["condition"] == "ctrl"]
)
print(test_metrics)

# save the dicts in json
with open(f"{save_dir}/test_metrics.json", "w") as f:
    json.dump(test_metrics, f)
# with open(f"{save_dir}/test_pert_res.json", "w") as f:
#     json.dump(test_pert_res, f)

deeper_res = deeper_analysis(pert_data.adata, test_res)
non_dropout_res = non_dropout_analysis(pert_data.adata, test_res)

metrics = ["pearson_delta", "pearson_delta_de"]
metrics_non_dropout = [
    "pearson_delta_top20_de_non_dropout",
    "pearson_top20_de_non_dropout",
]
subgroup_analysis = {}
for name in pert_data.subgroup["test_subgroup"].keys():
    subgroup_analysis[name] = {}
    for m in metrics:
        subgroup_analysis[name][m] = []

    for m in metrics_non_dropout:
        subgroup_analysis[name][m] = []

for name, pert_list in pert_data.subgroup["test_subgroup"].items():
    for pert in pert_list:
        for m in metrics:
            subgroup_analysis[name][m].append(deeper_res[pert][m])

        for m in metrics_non_dropout:
            subgroup_analysis[name][m].append(non_dropout_res[pert][m])

for name, result in subgroup_analysis.items():
    for m in result.keys():
        mean_value = np.mean(subgroup_analysis[name][m])
        logger.info("test_" + name + "_" + m + ": " + str(mean_value))
# Out:
# {'pearson': 0.9905142146627472, 'pearson_de': 0.9764816549060898, 'pearson_delta': 0.6455707120414657, 'pearson_de_delta': 0.7938968017804332}
# scGPT - INFO - test_combo_seen0_pearson_delta: nan
# scGPT - INFO - test_combo_seen0_pearson_delta_de: nan
# scGPT - INFO - test_combo_seen0_pearson_delta_top20_de_non_dropout: nan
# scGPT - INFO - test_combo_seen0_pearson_top20_de_non_dropout: nan
# scGPT - INFO - test_combo_seen1_pearson_delta: nan
# scGPT - INFO - test_combo_seen1_pearson_delta_de: nan
# scGPT - INFO - test_combo_seen1_pearson_delta_top20_de_non_dropout: nan
# scGPT - INFO - test_combo_seen1_pearson_top20_de_non_dropout: nan
# scGPT - INFO - test_combo_seen2_pearson_delta: nan
# scGPT - INFO - test_combo_seen2_pearson_delta_de: nan
# scGPT - INFO - test_combo_seen2_pearson_delta_top20_de_non_dropout: nan
# scGPT - INFO - test_combo_seen2_pearson_top20_de_non_dropout: nan
# scGPT - INFO - test_unseen_single_pearson_delta: 0.6455707120414657
# scGPT - INFO - test_unseen_single_pearson_delta_de: 0.7938968017804334
# scGPT - INFO - test_unseen_single_pearson_delta_top20_de_non_dropout: 0.7936529289624822
# scGPT - INFO - test_unseen_single_pearson_top20_de_non_dropout: 0.9736804748351122

# %%
test_metrics, test_pert_res = compute_metrics(test_res)
print(test_metrics)
# Out:
# {'mse': 0.00578324822371848, 'mse_de': 0.12851314989549859, 'pearson': 0.9905142146627472, 'pearson_de': 0.9764816549060896}
